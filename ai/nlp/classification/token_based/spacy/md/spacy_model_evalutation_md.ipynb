# %%
import spacy
import pandas as pd
from IPython.display import display

# Spécifiez le chemin du modèle spaCy local
model_checkpoint_spacy = r'C:\Users\vikne\Documents\Master 2\Semestre 9\Intelligence artificielle\Travel-Order-Resolver\ai\nlp\models\tokens_classification\old\spacy_md_old'

# Charger le modèle spaCy
try:
    nlp = spacy.load(model_checkpoint_spacy)
    print("Modèle spaCy chargé avec succès.")
except Exception as e:
    print(f"Erreur lors du chargement du modèle spaCy: {e}")

# Liste des phrases pour l'évaluation
phrases = [
    "Je pars de Paris et j'arrive à Marseille.",
    "Je vais à Bordeaux en partant de Toulouse.",
    "Mon trajet va de VILLIERS SUR LOIR à JARNY.",
    "Nous partons de Lyon et nous arrivons à Nice.",
    "Le départ est prévu à Lille, et l'arrivée se fera à Strasbourg.",
    "Mon itinéraire inclut un départ de Montpellier et une arrivée à Perpignan.",
    "Le train partira de Nantes pour arriver à Rennes.",
    "Un vol de Genève à Zurich est prévu demain matin.",
    "Je vais de Grenoble à Dijon en voiture.",
    "Je voyage de Bruxelles à Amsterdam ce week-end.",
    "L'itinéraire commence à Marseille et se termine à Toulon.",
    "Nous prenons un train de Rouen pour aller au Havre.",
    "Le départ sera à Limoges et l'arrivée à Poitiers.",
    "Je quitte Monaco pour aller à Menton.",
    "Le bus va de Caen à Cherbourg.",
    "Il part de Bayonne et arrive à Biarritz.",
    "Je vais de Chamonix à Annecy.",
    "Nous roulons de Bastia à Ajaccio.",
    "Le ferry part de Calais pour arriver à Douvres.",
    "Je pars de Bordeaux et j'arrive à Paris.",
    "Notre vol va de Madrid à Barcelone.",
    "Un trajet en voiture de Milan à Rome est prévu.",
    "Je vais à Paris en partant de Lyon."
]

# Liste pour stocker les résultats
results = []

# Fonction pour afficher les prédictions
for phrase in phrases:
    try:
        # Traiter la phrase avec spaCy
        doc = nlp(phrase)

        # Ajouter les entités détectées à la liste des résultats
        for ent in doc.ents:
            results.append({"Phrase": phrase, "Entity": ent.text, "Label": ent.label_})
    except Exception as e:
        print(f"Erreur lors du traitement de la phrase '{phrase}': {e}")

# Convertir les résultats en DataFrame
df = pd.DataFrame(results)

# Afficher le tableau
if not df.empty:
    display(df)
else:
    print("Aucune entité détectée.")
# Out:
# Modèle spaCy chargé avec succès.
#                                              Phrase             Entity Label
# 0         Je pars de Paris et j'arrive à Marseille.              Paris   DEP
# 1        Je vais à Bordeaux en partant de Toulouse.           Bordeaux   ARR
# 2       Mon trajet va de VILLIERS SUR LOIR à JARNY.  VILLIERS SUR LOIR   DEP
# 3       Mon trajet va de VILLIERS SUR LOIR à JARNY.              JARNY   ARR
# 4           Je vais de Grenoble à Dijon en voiture.           Grenoble   DEP
# 5           Je vais de Grenoble à Dijon en voiture.   Dijon en voiture   ARR
# 6   Je voyage de Bruxelles à Amsterdam ce week-end.          Bruxelles   DEP
# 7             Je quitte Monaco pour aller à Menton.             Menton   ARR
# 8                    Le bus va de Caen à Cherbourg.               Caen   DEP
# 9                    Le bus va de Caen à Cherbourg.          Cherbourg   ARR
# 10         Il part de Bayonne et arrive à Biarritz.           Biarritz   ARR
# 11                    Je vais de Chamonix à Annecy.           Chamonix   ARR
# 12                    Je vais de Chamonix à Annecy.             Annecy   ARR
# 13  Le ferry part de Calais pour arriver à Douvres.             Calais   DEP
# 14         Je pars de Bordeaux et j'arrive à Paris.           Bordeaux   DEP
# 15              Je vais à Paris en partant de Lyon.              Paris   ARR
# 16              Je vais à Paris en partant de Lyon.               Lyon   DEP

# %%
import spacy
import pandas as pd
from IPython.display import display

# Spécifiez le chemin du modèle spaCy local
model_checkpoint_spacy = r'C:\Users\vikne\Documents\Master 2\Semestre 9\Intelligence artificielle\Travel-Order-Resolver\ai\nlp\models\tokens_classification\spacy_md'

# Charger le modèle spaCy
try:
    nlp = spacy.load(model_checkpoint_spacy)
    print("Modèle spaCy chargé avec succès.")
except Exception as e:
    print(f"Erreur lors du chargement du modèle spaCy: {e}")

# Liste des phrases pour l'évaluation
phrases = [
    "Je pars de Paris et j'arrive à Marseille.",
    "Je vais à Bordeaux en partant de Toulouse.",
    "Mon trajet va de VILLIERS SUR LOIR à JARNY.",
    "Nous partons de Lyon et nous arrivons à Nice.",
    "Le départ est prévu à Lille, et l'arrivée se fera à Strasbourg.",
    "Mon itinéraire inclut un départ de Montpellier et une arrivée à Perpignan.",
    "Le train partira de Nantes pour arriver à Rennes.",
    "Un vol de Genève à Zurich est prévu demain matin.",
    "Je vais de Grenoble à Dijon en voiture.",
    "Je voyage de Bruxelles à Amsterdam ce week-end.",
    "L'itinéraire commence à Marseille et se termine à Toulon.",
    "Nous prenons un train de Rouen pour aller au Havre.",
    "Le départ sera à Limoges et l'arrivée à Poitiers.",
    "Je quitte Monaco pour aller à Menton.",
    "Le bus va de Caen à Cherbourg.",
    "Il part de Bayonne et arrive à Biarritz.",
    "Je vais de Chamonix à Annecy.",
    "Nous roulons de Bastia à Ajaccio.",
    "Le ferry part de Calais pour arriver à Douvres.",
    "Je pars de Bordeaux et j'arrive à Paris.",
    "Notre vol va de Madrid à Barcelone.",
    "Un trajet en voiture de Milan à Rome est prévu.",
    "Je vais à Paris en partant de Lyon."
]

# Liste pour stocker les résultats
results = []

# Fonction pour afficher les prédictions
for phrase in phrases:
    try:
        # Traiter la phrase avec spaCy
        doc = nlp(phrase)

        # Ajouter les entités détectées à la liste des résultats
        for ent in doc.ents:
            results.append({"Phrase": phrase, "Entity": ent.text, "Label": ent.label_})
    except Exception as e:
        print(f"Erreur lors du traitement de la phrase '{phrase}': {e}")

# Convertir les résultats en DataFrame
df = pd.DataFrame(results)

# Afficher le tableau
if not df.empty:
    display(df)
else:
    print("Aucune entité détectée.")
# Out:
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\util.py:910: UserWarning: [W095] Model 'fr_core_news_md' (3.8.0) was trained with spaCy v3.8.0 and may not be 100% compatible with the current version (3.7.2). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Modèle spaCy chargé avec succès.
#                                                Phrase             Entity Label
# 0           Je pars de Paris et j'arrive à Marseille.              Paris   DEP
# 1           Je pars de Paris et j'arrive à Marseille.          Marseille   ARR
# 2          Je vais à Bordeaux en partant de Toulouse.           Bordeaux   ARR
# 3          Je vais à Bordeaux en partant de Toulouse.           Toulouse   ARR
# 4         Mon trajet va de VILLIERS SUR LOIR à JARNY.  VILLIERS SUR LOIR   DEP
# 5         Mon trajet va de VILLIERS SUR LOIR à JARNY.              JARNY   ARR
# 6       Nous partons de Lyon et nous arrivons à Nice.               Nice   ARR
# 7   Le départ est prévu à Lille, et l'arrivée se f...         Strasbourg   DEP
# 8   Mon itinéraire inclut un départ de Montpellier...        Montpellier   ARR
# 9   Mon itinéraire inclut un départ de Montpellier...          Perpignan   DEP
# 10  Le train partira de Nantes pour arriver à Rennes.             Nantes   ARR
# 11  Le train partira de Nantes pour arriver à Rennes.             Rennes   ARR
# 12  Un vol de Genève à Zurich est prévu demain matin.             Genève   DEP
# 13            Je vais de Grenoble à Dijon en voiture.           Grenoble   ARR
# 14            Je vais de Grenoble à Dijon en voiture.              Dijon   ARR
# 15    Je voyage de Bruxelles à Amsterdam ce week-end.          Bruxelles   DEP
# 16  L'itinéraire commence à Marseille et se termin...          Marseille   ARR
# 17  L'itinéraire commence à Marseille et se termin...             Toulon   DEP
# 18  Nous prenons un train de Rouen pour aller au H...              Rouen   ARR
# 19  Nous prenons un train de Rouen pour aller au H...              Havre   ARR
# 20  Le départ sera à Limoges et l'arrivée à Poitiers.            Limoges   DEP
# 21  Le départ sera à Limoges et l'arrivée à Poitiers.           Poitiers   ARR
# 22              Je quitte Monaco pour aller à Menton.             Monaco   ARR
# 23              Je quitte Monaco pour aller à Menton.             Menton   DEP
# 24                     Le bus va de Caen à Cherbourg.               Caen   DEP
# 25                     Le bus va de Caen à Cherbourg.          Cherbourg   ARR
# 26           Il part de Bayonne et arrive à Biarritz.            Bayonne   ARR
# 27           Il part de Bayonne et arrive à Biarritz.           Biarritz   ARR
# 28                      Je vais de Chamonix à Annecy.           Chamonix   ARR
# 29                      Je vais de Chamonix à Annecy.             Annecy   ARR
# 30                  Nous roulons de Bastia à Ajaccio.             Bastia   ARR
# 31                  Nous roulons de Bastia à Ajaccio.            Ajaccio   ARR
# 32    Le ferry part de Calais pour arriver à Douvres.             Calais   DEP
# 33    Le ferry part de Calais pour arriver à Douvres.            Douvres   ARR
# 34           Je pars de Bordeaux et j'arrive à Paris.           Bordeaux   ARR
# 35                Je vais à Paris en partant de Lyon.              Paris   ARR
# 36                Je vais à Paris en partant de Lyon.               Lyon   DEP
