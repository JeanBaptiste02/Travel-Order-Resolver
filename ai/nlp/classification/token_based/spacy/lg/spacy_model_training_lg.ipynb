# %%
import spacy
from spacy.training import Example
import random
import pandas as pd
from sklearn.model_selection import train_test_split
from spacy.util import minibatch, compounding
from spacy.scorer import Scorer
import matplotlib.pyplot as plt
from collections import Counter
from pathlib import Path
import ast
import seaborn as sns
from tqdm import tqdm

print("Libraries imported")
# Out:
# Libraries imported

# %%
dataset_path = "C:/Users/vikne/Documents/Master 2/Semestre 9/Intelligence artificielle/Travel-Order-Resolver/ai/nlp/dataset/tokens/token.csv"
model_path = "C:/Users/vikne/Documents/Master 2/Semestre 9/Intelligence artificielle/Travel-Order-Resolver/ai/nlp/models/spacy_lg/"

print("paths defined")
# Out:
# paths defined

# %%
# Chargement du modèle spaCy
def load_model_with_progress(model_name):
    with tqdm(total=100, desc="Loading spaCy model") as pbar:
        nlp = spacy.load(model_name)
        pbar.update(100)
    return nlp

nlp = load_model_with_progress("fr_core_news_lg")
print("\n spaCy model Loaded successfully")
# Out:
# Loading spaCy model: 100%|██████████| 100/100 [00:18<00:00,  5.32it/s]
#  spaCy model Loaded successfully

# %%
ner = nlp.get_pipe("ner")
# Ajout des étiquettes personnalisées
labels = ["DEP", "ARR"]
for label in labels:
    ner.add_label(label)
    
print("Personnalised labels added successfully")
# Out:
# Personnalised labels added successfully

# %%
# Chargement des données avec une barre de progression
def load_dataset_with_progress(dataset_path):
    with tqdm(total=100, desc="Loading dataset\n") as pbar:
        dataset = pd.read_csv(dataset_path, delimiter=';', quotechar='"', names=["text", "tokens", "ner_tags", "spacy_ner_tags"])
        pbar.update(100)
    return dataset

dataset = load_dataset_with_progress(dataset_path)
print("Loaded dataset successfully")
# Out:
# Loading dataset
# Loading dataset  | 0/100 [00:00<?, ?it/s]
# Loading dataset██| 100/100 [00:05<00:00, 17.61it/s]
# : 100%|██████████| 100/100 [00:05<00:00, 17.60it/s]
# Loaded dataset successfully

# %%
# Normalisation des annotations
def safe_eval(val):
    try:
        val = val.replace('""', '"').replace("'", '"')
        return ast.literal_eval(val)
    except (ValueError, SyntaxError):
        return None

def is_entity_well_aligned(text, start, end):
    if start > 0 and text[start - 1].isalnum():
        return False
    if end < len(text) and text[end].isalnum():
        return False
    return True

# %%
# Préparation des données d'entraînement
print("Preparing training data...")
CONVERTED_TRAIN_DATA = []
misaligned_examples_count = 0

for _, item in tqdm(dataset.iterrows(), total=len(dataset)):
    tokens_str = item['tokens'].replace("'", '"')
    spacy_ner_tags_str = item['spacy_ner_tags'].replace("'", '"') if pd.notnull(item['spacy_ner_tags']) else None

    tokens = safe_eval(tokens_str)
    if tokens is None:
        continue

    entities = []
    if spacy_ner_tags_str:
        annotations = safe_eval(spacy_ner_tags_str)
        if annotations:
            for annotation in annotations:
                start, end, label = annotation['start'], annotation['end'], annotation['label']
                if is_entity_well_aligned(" ".join(tokens), start, end):
                    entities.append((start, end, label))
    # Si des entités sont trouvées ou même en l'absence d'annotations, ajouter l'exemple
    CONVERTED_TRAIN_DATA.append((" ".join(tokens), {"entities": entities}))

print("\n Training data prepared successfully")
examples = []
for text, annotations in CONVERTED_TRAIN_DATA:
    try:
        doc = nlp.make_doc(text)
        examples.append(Example.from_dict(doc, annotations))
    except ValueError:
        continue
# Out:
# Preparing training data...
# 100%|██████████| 435998/435998 [02:02<00:00, 3566.24it/s]
#  Training data prepared successfully
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve- moi un itinéraire d ax les thermes vers DR..." with entities "[(28, 42, 'ARR'), (48, 62, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je cherche un moyen d aller de Lille à Trier Hbf T..." with entities "[(31, 36, 'DEP'), (39, 57, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Planifie un déplacement efficace vers VIRIEU LE GR..." with entities "[(38, 53, 'ARR'), (68, 86, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve un moyen d atteindre Pont Saint Vincent dep..." with entities "[(28, 46, 'ARR'), (54, 73, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je souhaiterais aller à sainte marguerite d elle d..." with entities "[(24, 48, 'ARR'), (56, 78, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve- moi un itinéraire de l hopital d ax les th..." with entities "[(41, 55, 'ARR'), (74, 88, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Comment me rendre de VALLORCINE à Roche- Sur- Yon ..." with entities "[(21, 31, 'DEP'), (34, 53, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve un moyen d atteindre BETTEMBOURG depuis st ..." with entities "[(28, 39, 'ARR'), (47, 70, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je voudrais savoir comment me rendre à VIRIEU LE G..." with entities "[(39, 54, 'ARR'), (62, 80, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "J aimerais me rendre de la ville de rambervillers ..." with entities "[(36, 49, 'DEP'), (52, 63, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "J aimerais aller chez Haïder qui habite à l hopita..." with entities "[(55, 77, 'ARR'), (92, 113, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je vais à CAVAILLON en partant de lièpvre rte vanc..." with entities "[(10, 19, 'ARR'), (34, 56, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve un itinéraire pour aller à CHÂTEAUROUX CHAR..." with entities "[(34, 56, 'ARR'), (71, 92, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je pars de LILLE pour aller à l aéroport de trier ..." with entities "[(11, 16, 'DEP'), (44, 62, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je voudrais un billet Franois STE MARIE MS THÉÂTRE" with entities "[(22, 29, 'DEP'), (30, 53, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je suis en train de planifier un déplacement de Ro..." with entities "[(48, 69, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je veux aller à CAVAILLON depuis LIÈPVRE RTE VANCE..." with entities "[(16, 25, 'ARR'), (33, 55, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Pour rejoindre Asnath situé à LA CROIX EN TOURAINE..." with entities "[(30, 50, 'ARR'), (70, 93, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Pour rejoindre Veasna situé à sainte marguerite d ..." with entities "[(30, 54, 'ARR'), (74, 96, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "J aimerais connaître le chemin pour aller à sainte..." with entities "[(44, 68, 'ARR'), (76, 98, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve- moi un moyen de transport d Objat jusqu à ..." with entities "[(36, 41, 'DEP'), (71, 89, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Recherche le chemin entre nexon et Mouscron Moeskr..." with entities "[(26, 31, 'DEP'), (35, 55, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Ca met combien de temps pour aller de langres gend..." with entities "[(38, 57, 'DEP'), (60, 79, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je souhaite me rendre de RAMBERVILLERS jusqu à HAV..." with entities "[(25, 38, 'DEP'), (47, 58, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je voudrais savoir comment me rendre de Franois à ..." with entities "[(40, 47, 'DEP'), (50, 73, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve- moi un moyen de transport de la place cent..." with entities "[(57, 64, 'DEP'), (91, 113, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "De la gare de ROMORANTIN BA G. R. vers la gare de ..." with entities "[(14, 32, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Partez pour ARQUES en partant de pfaffenhoffen mai..." with entities "[(12, 18, 'ARR'), (33, 56, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je voudrais savoir comment me rendre à la gare de ..." with entities "[(50, 59, 'ARR'), (67, 84, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je voudrais savoir comment me rendre à CAVAILLON d..." with entities "[(39, 48, 'ARR'), (56, 78, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Indique- moi le trajet d OBERNAI à rambervillers 1..." with entities "[(25, 32, 'DEP'), (35, 57, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je souhaite me rendre de St Gervais Ch Lpa. jusqu ..." with entities "[(25, 43, 'DEP'), (52, 70, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Mon trajet va de l hopital de ROMORANTIN BA G. R. ..." with entities "[(30, 48, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "J aimerais aller à Albertville en partant de REIPE..." with entities "[(19, 30, 'ARR'), (45, 63, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve- moi un itinéraire pour aller d Obernai à r..." with entities "[(39, 46, 'DEP'), (49, 71, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je recherche un itinéraire de ROMORANTIN BA G. R. ..." with entities "[(30, 48, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je voudrais un billet Lille Trier Hbf Trèves)" with entities "[(22, 27, 'DEP'), (28, 46, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Dirige- moi de Niedermodern/ Uberach à font- romeu..." with entities "[(37, 59, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "J aimerais aller à narbonne en partant de SÈLESTAT..." with entities "[(19, 27, 'ARR'), (42, 62, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je souhaite organiser mon trajet pour me rendre ch..." with entities "[(74, 83, 'ARR'), (104, 126, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je pars de l hopital de saint gilles croix de vie ..." with entities "[(24, 49, 'DEP'), (68, 90, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "J aimerais connaître le chemin pour aller à ARQUES..." with entities "[(44, 50, 'ARR'), (58, 81, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "En partant de St- Gervais- Ch- Lpa. je voudrais sa..." with entities "[(85, 103, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je veux aller à chaumont depuis lichtenberg eglise..." with entities "[(16, 24, 'ARR'), (32, 53, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Comment aller à CAVAILLON depuis lièpvre rte vance..." with entities "[(16, 25, 'ARR'), (33, 55, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Mon trajet va de VALLORCINE à Roche Sur Yon La" with entities "[(17, 27, 'DEP'), (30, 49, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je prévois un voyage de l hopital de Rambervillers..." with entities "[(37, 50, 'DEP'), (53, 64, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trace un parcours de l aéroport de Romorantin- Lyc..." with entities "[(35, 56, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Recherche le chemin entre saint gilles croix de vi..." with entities "[(26, 51, 'DEP'), (55, 77, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve un moyen d atteindre l aéroport de sainte m..." with entities "[(42, 66, 'ARR'), (74, 96, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je voudrais savoir comment me rendre chez Souhane,..." with entities "[(94, 116, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Mon trajet va de saint gilles croix de vie à L Isl..." with entities "[(17, 42, 'DEP'), (45, 67, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Recherche le trajet le plus court vers carnoules à..." with entities "[(39, 48, 'ARR'), (61, 78, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve- moi un moyen de transport d OBERNAI vers r..." with entities "[(36, 43, 'DEP'), (49, 71, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve- moi un itinéraire d ax les thermes vers dr..." with entities "[(28, 42, 'ARR'), (48, 62, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je désire aller à le tréport- mers- les- b depuis ..." with entities "[(18, 39, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve- moi un moyen de transport d Obernai jusqu ..." with entities "[(36, 43, 'DEP'), (52, 74, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Depuis langres gendarmerie vers RIOM_ES_M_LA_POSTE..." with entities "[(7, 26, 'DEP'), (32, 51, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve un itinéraire de MAURIAC à mans le" with entities "[(24, 31, 'DEP'), (34, 44, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je suis en train de planifier un déplacement de la..." with entities "[(60, 67, 'DEP'), (82, 105, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Comment puis- je me rendre d avallon à NEUSTADT WE..." with entities "[(29, 36, 'DEP'), (39, 61, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je cherche un moyen d aller de rambervillers à hav..." with entities "[(31, 44, 'DEP'), (47, 58, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Ca met combien de temps pour aller de Lille à Trie..." with entities "[(38, 43, 'DEP'), (46, 64, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je prévois un voyage de l hopital de vallorcine à ..." with entities "[(37, 47, 'DEP'), (50, 69, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Peux- tu m aider à trouver mon chemin d objat à fr..." with entities "[(40, 45, 'DEP'), (48, 66, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve le meilleur itinéraire de LANGRES GENDARMER..." with entities "[(33, 52, 'DEP'), (55, 74, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Indique- moi le trajet le plus simple d Oderen ver..." with entities "[(40, 46, 'DEP'), (52, 73, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "J aimerais connaître le chemin pour aller à Commen..." with entities "[(44, 53, 'ARR'), (74, 95, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "J aimerais connaître le chemin pour aller à NARBON..." with entities "[(44, 52, 'ARR'), (60, 80, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je voudrais savoir comment me rendre à la gare de ..." with entities "[(50, 58, 'ARR'), (66, 86, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve le meilleur itinéraire de la gare de Saint ..." with entities "[(44, 69, 'DEP'), (72, 91, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je recherche un itinéraire pour aller à Albertvill..." with entities "[(40, 51, 'ARR'), (66, 84, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Mon trajet va de MAURIAC à mans le" with entities "[(17, 24, 'DEP'), (27, 37, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "J aimerais aller chez Florianne qui habite à l hop..." with entities "[(55, 71, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "J aimerais connaître le chemin pour aller à Châten..." with entities "[(44, 53, 'ARR'), (61, 78, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Pourrais- tu m aider à planifier le trajet d obern..." with entities "[(45, 52, 'DEP'), (58, 80, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve le meilleur itinéraire de toulon à BRESSE C..." with entities "[(33, 39, 'DEP'), (42, 61, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve le meilleur itinéraire de ROMORANTIN BA G. ..." with entities "[(33, 51, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "J aimerais me rendre de ROANNE à dompierre halte r..." with entities "[(24, 30, 'DEP'), (33, 54, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je veux me rendre chez mon ami Anel qui habite à l..." with entities "[(82, 93, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je recherche un itinéraire pour aller à la gare de..." with entities "[(51, 67, 'ARR'), (82, 93, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "De objat à frohmuhl- lavoir)" with entities "[(3, 8, 'DEP'), (11, 29, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je veux aller à Landau Pfalz Hbf depuis Garde La" with entities "[(16, 32, 'ARR'), (40, 51, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je cherche le chemin pour aller à carnoules depuis..." with entities "[(34, 43, 'ARR'), (51, 68, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je cherche un moyen d aller de LANGRES GENDARMERIE..." with entities "[(31, 50, 'DEP'), (65, 84, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je souhaite me rendre de la ville de Lille jusqu à..." with entities "[(37, 42, 'DEP'), (63, 81, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Pour rejoindre Takfarinas situé à puy en velay le ..." with entities "[(68, 86, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je voudrais savoir comment me rendre de ROMORANTIN..." with entities "[(40, 58, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je prévois un voyage de St Gervais Ch Lpa. à puy e..." with entities "[(24, 42, 'DEP'), (45, 63, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je cherche le chemin pour aller à ARNAC POMPADOUR ..." with entities "[(34, 49, 'ARR'), (57, 79, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Ca met combien de temps pour aller de SAINT GILLES..." with entities "[(38, 63, 'DEP'), (66, 88, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je veux aller à Pont Saint Vincent depuis DOSSENHE..." with entities "[(16, 34, 'ARR'), (42, 61, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve un itinéraire pour aller à ax les thermes e..." with entities "[(34, 48, 'ARR'), (63, 77, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je vais à Chalindrey en partant de Haguenau Moulin..." with entities "[(10, 20, 'ARR'), (35, 56, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve un moyen d atteindre l aéroport de LA CROIX..." with entities "[(42, 62, 'ARR'), (70, 93, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Montre- moi le trajet pour aller à l hopital d Alb..." with entities "[(47, 58, 'ARR'), (73, 91, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve- moi le chemin d Avallon à Neustadt Weinstr..." with entities "[(24, 31, 'DEP'), (34, 56, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "De Oderen vers FÉNÉTRANGE GENDARM ." with entities "[(3, 9, 'DEP'), (15, 36, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je suis en train de planifier un déplacement de la..." with entities "[(60, 78, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Aller à VIRIEU LE GRAND en partant de ROMORANTIN B..." with entities "[(8, 23, 'ARR'), (38, 56, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Partez pour chaumont en partant de lichtenberg egl..." with entities "[(12, 20, 'ARR'), (35, 56, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je voudrais savoir comment me rendre de RAMBERVILL..." with entities "[(40, 53, 'DEP'), (56, 67, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je pars de VALLORCINE pour aller à Roche Sur Yon L..." with entities "[(11, 21, 'DEP'), (35, 54, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "J aimerais aller à la place centrale de Saint Germ..." with entities "[(40, 64, 'ARR'), (100, 114, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve un itinéraire pour aller à Châtenois depuis..." with entities "[(34, 43, 'ARR'), (51, 68, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Partez pour ARQUES en partant de Pfaffenhoffen Mai..." with entities "[(12, 18, 'ARR'), (33, 56, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je pars de Toulon vers BRESSE CLAUDEL LA)" with entities "[(11, 17, 'DEP'), (23, 42, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Recherche le trajet le plus court vers sainte marg..." with entities "[(39, 63, 'ARR'), (76, 98, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je veux aller à ARQUES depuis l hopital de Pfaffen..." with entities "[(16, 22, 'ARR'), (43, 66, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Mon trajet va de Franois à STE MARIE MS THÉÂTRE ." with entities "[(17, 24, 'DEP'), (27, 50, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je cherche un moyen d aller de VALLORCINE à Roche-..." with entities "[(31, 41, 'DEP'), (44, 63, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je souhaite me rendre de Mauriac jusqu à Mans Le" with entities "[(25, 32, 'DEP'), (41, 51, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je suis en train de planifier un déplacement de la..." with entities "[(48, 67, 'DEP'), (70, 89, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# ...
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Comment atteindre Chalindrey depuis Haguenau Mouli..." with entities "[(18, 28, 'ARR'), (36, 57, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve un moyen d atteindre l aéroport de Châteaur..." with entities "[(42, 64, 'ARR'), (72, 93, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Peux- tu me guider d obernai vers rambervillers 11..." with entities "[(21, 28, 'DEP'), (34, 56, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Partez pour l aéroport de Châteauroux Charmilles e..." with entities "[(26, 48, 'ARR'), (63, 84, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Y a- t- il un moyen d aller de rambervillers à hav..." with entities "[(45, 56, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Planifie un déplacement vers la maison de Abdassam..." with entities "[(100, 118, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je pars de ROANNE pour aller à l aéroport de dompi..." with entities "[(11, 17, 'DEP'), (45, 66, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je pars de Nexon en direction de MOUSCRON MOESKROE..." with entities "[(11, 16, 'DEP'), (33, 53, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "C est quoi le trajet de SAINT GILLES CROIX DE VIE ..." with entities "[(24, 49, 'DEP'), (52, 74, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Ca met combien de temps un Nexon MOUSCRON MOESKROE..." with entities "[(27, 32, 'DEP'), (33, 53, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je souhaiterais aller à l aéroport de narbonne dep..." with entities "[(38, 46, 'ARR'), (54, 74, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Indique- moi le chemin depuis la ville d obernai j..." with entities "[(41, 48, 'DEP'), (57, 79, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Recherche le chemin le plus court entre Agen et la..." with entities "[(40, 44, 'DEP'), (69, 90, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Pourrais- tu m indiquer comment aller d avallon à ..." with entities "[(40, 47, 'DEP'), (50, 72, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je souhaiterais aller à l aéroport de Manosque dep..." with entities "[(38, 46, 'ARR'), (54, 76, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je veux aller à CAVAILLON depuis l hopital de LIÈP..." with entities "[(16, 25, 'ARR'), (46, 68, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Pour rejoindre Josyanne situé à l aéroport d aix- ..." with entities "[(93, 110, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "C est quoi le trajet de Franois à STE MARIE/ MS TH..." with entities "[(24, 31, 'DEP'), (34, 57, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "J aimerais aller chez Divina qui habite à Routot P..." with entities "[(42, 64, 'ARR'), (79, 100, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Aller de l hopital de MAURIAC à mans le" with entities "[(22, 29, 'DEP'), (32, 42, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je veux aller de NEXON à Mouscron Moeskroen" with entities "[(17, 22, 'DEP'), (25, 45, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Comment atteindre la croix en touraine à partir de..." with entities "[(18, 38, 'ARR'), (51, 74, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je pars de NEXON pour aller à Mouscron Moeskroen" with entities "[(11, 16, 'DEP'), (30, 50, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Recherche le chemin le plus court entre Saint- Bon..." with entities "[(90, 109, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je veux aller de l hopital de romorantin ba g. r. ..." with entities "[(30, 48, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "J aimerais connaître le chemin pour aller de l hop..." with entities "[(58, 79, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "En partant de ROMORANTIN BA G. R. je voudrais savo..." with entities "[(14, 32, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve- moi le chemin d Oderen à la gare de FÉNÉTR..." with entities "[(24, 30, 'DEP'), (44, 65, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "De l hopital de ROANNE à dompierre halte rout ." with entities "[(16, 22, 'DEP'), (25, 46, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Comment aller à Commentry depuis Romorantin- Lycée..." with entities "[(16, 25, 'ARR'), (33, 54, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Trouve un itinéraire de la place centrale de langr..." with entities "[(45, 64, 'DEP'), (88, 107, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Je souhaiterais aller à l aéroport de landau pfalz..." with entities "[(38, 54, 'ARR'), (62, 73, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Pourrais- tu me trouver un itinéraire pour me rend..." with entities "[(94, 107, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Indique- moi le trajet le plus simple depuis breil..." with entities "[(75, 94, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "De romorantin ba g. r. vers VIRIEU LE GRAND" with entities "[(3, 21, 'DEP')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Recherche le chemin entre la gare de Franois et ST..." with entities "[(37, 44, 'DEP'), (48, 71, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "J aimerais me rendre de BOURGES GARE ROUTIÈRE à St..." with entities "[(24, 45, 'DEP'), (48, 71, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\vikne\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Comment me rendre de SAINT BONNET DE ROCHEFORT à l..." with entities "[(21, 46, 'DEP'), (49, 68, 'ARR')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(

# %%
# Répartition des données en ensembles d'entraînement, test et validation
train_data, test_valid_data = train_test_split(examples, test_size=0.5, random_state=42)
test_data, valid_data = train_test_split(test_valid_data, test_size=0.5, random_state=42)

print(f"Train data: {len(train_data)} examples")
print(f"Test data: {len(test_data)} examples")
print(f"Validation data: {len(valid_data)} examples")
# Out:
# Train data: 167283 examples
# Test data: 83642 examples
# Validation data: 83642 examples

# %%
# Entraînement du modèle
def evaluate(nlp, examples):
    scorer = Scorer()
    examples_to_score = []
    for example in examples:
        pred_doc = nlp(example.text)
        scored_example = Example(pred_doc, example.reference)
        examples_to_score.append(scored_example)
    return scorer.score(examples_to_score)

losses_hist, f1_hist, recall_hist, precision_hist = [], [], [], []
epochs = 20

with nlp.disable_pipes(*[pipe for pipe in nlp.pipe_names if pipe != "ner"]):
    optimizer = nlp.begin_training()
    for epoch in tqdm(range(epochs), desc="Training model"):
        random.shuffle(train_data)
        losses = {}
        batches = list(minibatch(train_data, size=compounding(16.0, 64.0, 1.001)))
        for batch in tqdm(batches, desc=f"Epoch {epoch+1}/{epochs}", leave=False):
            nlp.update(batch, drop=0.2, losses=losses, sgd=optimizer)
        print(f"Loss at epoch {epoch}: {losses}")
        losses_hist.append(losses['ner'])

        # Validation
        valid_scores = evaluate(nlp, valid_data)
        f1_hist.append(valid_scores['ents_f'])
        recall_hist.append(valid_scores['ents_r'])
        precision_hist.append(valid_scores['ents_p'])
# Out:
# Training model:   0%|          | 0/20 [00:00<?, ?it/s]
# Loss at epoch 0: {'ner': 87182.44754684858}
# Training model:   5%|▌         | 1/20 [32:01<10:08:29, 1921.54s/it]
# Loss at epoch 1: {'ner': 54491.94261283485}
# Training model:  10%|█         | 2/20 [1:10:06<10:40:35, 2135.30s/it]
# Loss at epoch 2: {'ner': 48189.99118910819}
# Training model:  15%|█▌        | 3/20 [1:48:31<10:26:59, 2212.91s/it]
# Loss at epoch 3: {'ner': 44424.6812234142}
# Training model:  20%|██        | 4/20 [2:27:56<10:06:07, 2272.94s/it]
# Loss at epoch 4: {'ner': 42218.356510438054}
# Training model:  25%|██▌       | 5/20 [3:08:07<9:40:41, 2322.76s/it]
# Loss at epoch 5: {'ner': 40981.81548147615}
# Training model:  30%|███       | 6/20 [3:48:03<9:07:45, 2347.56s/it]
# Loss at epoch 6: {'ner': 39958.57922685833}
# Training model:  35%|███▌      | 7/20 [4:28:27<8:34:03, 2372.56s/it]
# Loss at epoch 7: {'ner': 39051.757524935805}
# Training model:  40%|████      | 8/20 [5:09:35<8:00:34, 2402.85s/it]
# Loss at epoch 8: {'ner': 38385.3821167507}
# Training model:  45%|████▌     | 9/20 [5:43:37<6:59:50, 2290.08s/it]
# Loss at epoch 9: {'ner': 37802.05538065541}
# Training model:  50%|█████     | 10/20 [6:15:16<6:01:32, 2169.26s/it]
# Loss at epoch 10: {'ner': 37456.95764517822}
# Training model:  55%|█████▌    | 11/20 [6:48:14<5:16:37, 2110.82s/it]
# Loss at epoch 11: {'ner': 36944.556465456735}
# Training model:  60%|██████    | 12/20 [7:22:15<4:38:36, 2089.58s/it]
# Loss at epoch 12: {'ner': 36779.73916096069}
# Training model:  65%|██████▌   | 13/20 [7:55:30<4:00:27, 2061.06s/it]
# Loss at epoch 13: {'ner': 36365.04079626054}
# Training model:  70%|███████   | 14/20 [8:30:47<3:27:47, 2077.88s/it]
# Loss at epoch 14: {'ner': 36277.491174138806}
# Training model:  75%|███████▌  | 15/20 [9:05:36<2:53:26, 2081.35s/it]
# Loss at epoch 15: {'ner': 36181.94673746554}
# Training model:  80%|████████  | 16/20 [9:38:53<2:17:02, 2055.67s/it]
# Loss at epoch 16: {'ner': 35912.630030472}
# Training model:  85%|████████▌ | 17/20 [10:15:01<1:44:28, 2089.63s/it]
# Loss at epoch 17: {'ner': 35710.600081175005}
# Training model:  90%|█████████ | 18/20 [12:07:27<1:56:17, 3488.92s/it]
# Loss at epoch 18: {'ner': 35538.252041934706}
# Training model:  95%|█████████▌| 19/20 [12:50:12<53:31, 3211.34s/it]
# Loss at epoch 19: {'ner': 35496.56585022536}
# Training model: 100%|██████████| 20/20 [13:20:37<00:00, 2401.87s/it]

# %%
# Évaluation
valid_scores = evaluate(nlp, valid_data)
print(f"Validation F1 Score: {valid_scores['ents_f']}, Precision: {valid_scores['ents_p']}, Recall: {valid_scores['ents_r']}")

output_dir = Path(model_path)
output_dir.mkdir(parents=True, exist_ok=True)
nlp.to_disk(output_dir)

test_scores = evaluate(nlp, test_data)
print(f"Test F1 Score: {test_scores['ents_f']}, Precision: {test_scores['ents_p']}, Recall: {test_scores['ents_r']}")
# Out:
# Validation F1 Score: 0.8655607515426548, Precision: 0.875775180233779, Recall: 0.8555818437931647
# Test F1 Score: 0.8661362658113606, Precision: 0.8769734714821948, Recall: 0.8555636323737159

# %%
# Visualisation des performances
def draw_scores(losses_hist, f1_hist, recall_hist, precision_hist):
    fig, axs = plt.subplots(2, 2, figsize=(12, 8))
    axs[0, 0].plot(losses_hist, label="Loss")
    axs[0, 1].plot(f1_hist, label="F1 Score", color="orange")
    axs[1, 0].plot(recall_hist, label="Recall", color="green")
    axs[1, 1].plot(precision_hist, label="Precision", color="blue")
    for ax in axs.flat:
        ax.legend()
    plt.tight_layout()
    plt.show()

draw_scores(losses_hist, f1_hist, recall_hist, precision_hist)

# %%
# Test du modèle
test_sentences = [
    "Je pars de Paris et j'arrive à Marseille.",
    "Je vais à Bordeaux en partant de Toulouse.",
    "Mon trajet va de VILLIERS SUR LOIR à JARNY.",
    "Nous partons de Lyon et nous arrivons à Nice.",
    "Le départ est prévu à Lille, et l'arrivée se fera à Strasbourg.",
    "Mon itinéraire inclut un départ de Montpellier et une arrivée à Perpignan.",
    "Le train partira de Nantes pour arriver à Rennes.",
    "Un vol de Genève à Zurich est prévu demain matin.",
    "Je vais de Grenoble à Dijon en voiture.",
    "Je voyage de Bruxelles à Amsterdam ce week-end.",
    "L'itinéraire commence à Marseille et se termine à Toulon.",
    "Nous prenons un train de Rouen pour aller au Havre.",
    "Le départ sera à Limoges et l'arrivée à Poitiers.",
    "Je quitte Monaco pour aller à Menton.",
    "Le bus va de Caen à Cherbourg.",
    "Il part de Bayonne et arrive à Biarritz.",
    "Je vais de Chamonix à Annecy.",
    "Nous roulons de Bastia à Ajaccio.",
    "Le ferry part de Calais pour arriver à Douvres.",
    "Je pars de Bordeaux et j'arrive à Paris.",
    "Notre vol va de Madrid à Barcelone.",
    "Un trajet en voiture de Milan à Rome est prévu.",
    "Le départ est de Zurich et l'arrivée est à Lausanne.",
    "Je vais à Londres depuis Manchester.",
    "Le train va de Tokyo à Kyoto."
]

def test_ner_model(nlp, sentences):
    for sentence in sentences:
        doc = nlp(sentence)
        print(f"\nPhrase : {sentence}")
        print("Entités reconnues :")
        for ent in doc.ents:
            print(f" - Texte : {ent.text}, Label : {ent.label_}, Position : ({ent.start_char}, {ent.end_char})")

test_ner_model(nlp, test_sentences)
# Out:
# Phrase : Je pars de Paris et j'arrive à Marseille.
# Entités reconnues :
#  - Texte : Paris, Label : DEP, Position : (11, 16)
#  - Texte : Marseille, Label : ARR, Position : (31, 40)
#
# Phrase : Je vais à Bordeaux en partant de Toulouse.
# Entités reconnues :
#  - Texte : Bordeaux, Label : ARR, Position : (10, 18)
#
# Phrase : Mon trajet va de VILLIERS SUR LOIR à JARNY.
# Entités reconnues :
#  - Texte : VILLIERS SUR LOIR, Label : DEP, Position : (17, 34)
#  - Texte : JARNY, Label : ARR, Position : (37, 42)
#
# Phrase : Nous partons de Lyon et nous arrivons à Nice.
# Entités reconnues :
#
# Phrase : Le départ est prévu à Lille, et l'arrivée se fera à Strasbourg.
# Entités reconnues :
#
# Phrase : Mon itinéraire inclut un départ de Montpellier et une arrivée à Perpignan.
# Entités reconnues :
#  - Texte : Montpellier, Label : ARR, Position : (35, 46)
#
# Phrase : Le train partira de Nantes pour arriver à Rennes.
# Entités reconnues :
#
# Phrase : Un vol de Genève à Zurich est prévu demain matin.
# Entités reconnues :
#  - Texte : Genève, Label : DEP, Position : (10, 16)
#  - Texte : Zurich, Label : ARR, Position : (19, 25)
#
# Phrase : Je vais de Grenoble à Dijon en voiture.
# Entités reconnues :
#  - Texte : Grenoble, Label : DEP, Position : (11, 19)
#  - Texte : Dijon, Label : ARR, Position : (22, 27)
#
# Phrase : Je voyage de Bruxelles à Amsterdam ce week-end.
# Entités reconnues :
#  - Texte : Bruxelles, Label : DEP, Position : (13, 22)
#
# Phrase : L'itinéraire commence à Marseille et se termine à Toulon.
# Entités reconnues :
#
# Phrase : Nous prenons un train de Rouen pour aller au Havre.
# Entités reconnues :
#
# Phrase : Le départ sera à Limoges et l'arrivée à Poitiers.
# Entités reconnues :
#  - Texte : Limoges, Label : DEP, Position : (17, 24)
#
# Phrase : Je quitte Monaco pour aller à Menton.
# Entités reconnues :
#  - Texte : Menton, Label : DEP, Position : (30, 36)
#
# Phrase : Le bus va de Caen à Cherbourg.
# Entités reconnues :
#  - Texte : Caen, Label : DEP, Position : (13, 17)
#  - Texte : Cherbourg, Label : ARR, Position : (20, 29)
#
# Phrase : Il part de Bayonne et arrive à Biarritz.
# Entités reconnues :
#  - Texte : Bayonne, Label : DEP, Position : (11, 18)
#  - Texte : Biarritz, Label : ARR, Position : (31, 39)
#
# Phrase : Je vais de Chamonix à Annecy.
# Entités reconnues :
#  - Texte : Chamonix, Label : DEP, Position : (11, 19)
#  - Texte : Annecy, Label : ARR, Position : (22, 28)
#
# Phrase : Nous roulons de Bastia à Ajaccio.
# Entités reconnues :
#
# Phrase : Le ferry part de Calais pour arriver à Douvres.
# Entités reconnues :
#
# Phrase : Je pars de Bordeaux et j'arrive à Paris.
# Entités reconnues :
#  - Texte : Bordeaux, Label : DEP, Position : (11, 19)
#
# Phrase : Notre vol va de Madrid à Barcelone.
# Entités reconnues :
#  - Texte : Barcelone, Label : ARR, Position : (25, 34)
#
# Phrase : Un trajet en voiture de Milan à Rome est prévu.
# Entités reconnues :
#
# Phrase : Le départ est de Zurich et l'arrivée est à Lausanne.
# Entités reconnues :
#
# Phrase : Je vais à Londres depuis Manchester.
# Entités reconnues :
#  - Texte : Manchester, Label : DEP, Position : (25, 35)
#
# Phrase : Le train va de Tokyo à Kyoto.
# Entités reconnues :
