# %%
import spacy
import pandas as pd
from IPython.display import display

# Spécifiez le chemin du modèle spaCy local
model_checkpoint_spacy = r'C:\Users\vikne\Documents\Master 2\Semestre 9\Intelligence artificielle\Travel-Order-Resolver\ai\nlp\models\tokens_classification\old\spacy_sm_old'

# Charger le modèle spaCy
try:
    nlp = spacy.load(model_checkpoint_spacy)
    print("Modèle spaCy chargé avec succès.")
except Exception as e:
    print(f"Erreur lors du chargement du modèle spaCy: {e}")

# Liste des phrases pour l'évaluation
phrases = [
    "Je pars de Paris et j'arrive à Marseille.",
    "Je vais à Bordeaux en partant de Toulouse.",
    "Mon trajet va de VILLIERS SUR LOIR à JARNY.",
    "Nous partons de Lyon et nous arrivons à Nice.",
    "Le départ est prévu à Lille, et l'arrivée se fera à Strasbourg.",
    "Mon itinéraire inclut un départ de Montpellier et une arrivée à Perpignan.",
    "Le train partira de Nantes pour arriver à Rennes.",
    "Un vol de Genève à Zurich est prévu demain matin.",
    "Je vais de Grenoble à Dijon en voiture.",
    "Je voyage de Bruxelles à Amsterdam ce week-end.",
    "L'itinéraire commence à Marseille et se termine à Toulon.",
    "Nous prenons un train de Rouen pour aller au Havre.",
    "Le départ sera à Limoges et l'arrivée à Poitiers.",
    "Je quitte Monaco pour aller à Menton.",
    "Le bus va de Caen à Cherbourg.",
    "Il part de Bayonne et arrive à Biarritz.",
    "Je vais de Chamonix à Annecy.",
    "Nous roulons de Bastia à Ajaccio.",
    "Le ferry part de Calais pour arriver à Douvres.",
    "Je pars de Bordeaux et j'arrive à Paris.",
    "Notre vol va de Madrid à Barcelone.",
    "Un trajet en voiture de Milan à Rome est prévu.",
    "Je vais à Paris en partant de Lyon."
]

# Liste pour stocker les résultats
results = []

# Fonction pour afficher les prédictions
for phrase in phrases:
    try:
        # Traiter la phrase avec spaCy
        doc = nlp(phrase)

        # Ajouter les entités détectées à la liste des résultats
        for ent in doc.ents:
            results.append({"Phrase": phrase, "Entity": ent.text, "Label": ent.label_})
    except Exception as e:
        print(f"Erreur lors du traitement de la phrase '{phrase}': {e}")

# Convertir les résultats en DataFrame
df = pd.DataFrame(results)

# Afficher le tableau
if not df.empty:
    display(df)
else:
    print("Aucune entité détectée.")
# Out:
# Modèle spaCy chargé avec succès.
#                                          Phrase             Entity Label
# 0     Je pars de Paris et j'arrive à Marseille.              Paris   DEP
# 1    Je vais à Bordeaux en partant de Toulouse.           Bordeaux   ARR
# 2   Mon trajet va de VILLIERS SUR LOIR à JARNY.  VILLIERS SUR LOIR   DEP
# 3   Mon trajet va de VILLIERS SUR LOIR à JARNY.              JARNY   ARR
# 4       Je vais de Grenoble à Dijon en voiture.           Grenoble   ARR
# 5                Le bus va de Caen à Cherbourg.               Caen   DEP
# 6                Le bus va de Caen à Cherbourg.          Cherbourg   ARR
# 7                 Je vais de Chamonix à Annecy.           Chamonix   DEP
# 8                 Je vais de Chamonix à Annecy.             Annecy   ARR
# 9           Je vais à Paris en partant de Lyon.              Paris   ARR
# 10          Je vais à Paris en partant de Lyon.               Lyon   DEP

# %%
import spacy
import pandas as pd
from IPython.display import display

# Spécifiez le chemin du modèle spaCy local
model_checkpoint_spacy = r'C:\Users\vikne\Documents\Master 2\Semestre 9\Intelligence artificielle\Travel-Order-Resolver\ai\nlp\models\tokens_classification\spacy_sm'

# Charger le modèle spaCy
try:
    nlp = spacy.load(model_checkpoint_spacy)
    print("Modèle spaCy chargé avec succès.")
except Exception as e:
    print(f"Erreur lors du chargement du modèle spaCy: {e}")

# Liste des phrases pour l'évaluation
phrases = [
    "Je pars de Paris et j'arrive à Marseille.",
    "Je vais à Bordeaux en partant de Toulouse.",
    "Mon trajet va de VILLIERS SUR LOIR à JARNY.",
    "Nous partons de Lyon et nous arrivons à Nice.",
    "Le départ est prévu à Lille, et l'arrivée se fera à Strasbourg.",
    "Mon itinéraire inclut un départ de Montpellier et une arrivée à Perpignan.",
    "Le train partira de Nantes pour arriver à Rennes.",
    "Un vol de Genève à Zurich est prévu demain matin.",
    "Je vais de Grenoble à Dijon en voiture.",
    "Je voyage de Bruxelles à Amsterdam ce week-end.",
    "L'itinéraire commence à Marseille et se termine à Toulon.",
    "Nous prenons un train de Rouen pour aller au Havre.",
    "Le départ sera à Limoges et l'arrivée à Poitiers.",
    "Je quitte Monaco pour aller à Menton.",
    "Le bus va de Caen à Cherbourg.",
    "Il part de Bayonne et arrive à Biarritz.",
    "Je vais de Chamonix à Annecy.",
    "Nous roulons de Bastia à Ajaccio.",
    "Le ferry part de Calais pour arriver à Douvres.",
    "Je pars de Bordeaux et j'arrive à Paris.",
    "Notre vol va de Madrid à Barcelone.",
    "Un trajet en voiture de Milan à Rome est prévu.",
    "Je vais à Paris en partant de Lyon."
]

# Liste pour stocker les résultats
results = []

# Fonction pour afficher les prédictions
for phrase in phrases:
    try:
        # Traiter la phrase avec spaCy
        doc = nlp(phrase)

        # Ajouter les entités détectées à la liste des résultats
        for ent in doc.ents:
            results.append({"Phrase": phrase, "Entity": ent.text, "Label": ent.label_})
    except Exception as e:
        print(f"Erreur lors du traitement de la phrase '{phrase}': {e}")

# Convertir les résultats en DataFrame
df = pd.DataFrame(results)

# Afficher le tableau
if not df.empty:
    display(df)
else:
    print("Aucune entité détectée.")
# Out:
# Modèle spaCy chargé avec succès.
#                                                Phrase             Entity Label
# 0           Je pars de Paris et j'arrive à Marseille.              Paris   DEP
# 1          Je vais à Bordeaux en partant de Toulouse.           Bordeaux   ARR
# 2          Je vais à Bordeaux en partant de Toulouse.           Toulouse   ARR
# 3         Mon trajet va de VILLIERS SUR LOIR à JARNY.  VILLIERS SUR LOIR   DEP
# 4         Mon trajet va de VILLIERS SUR LOIR à JARNY.              JARNY   ARR
# 5       Nous partons de Lyon et nous arrivons à Nice.               Nice   ARR
# 6   Un vol de Genève à Zurich est prévu demain matin.             Genève   DEP
# 7   Un vol de Genève à Zurich est prévu demain matin.             Zurich   ARR
# 8             Je vais de Grenoble à Dijon en voiture.           Grenoble   ARR
# 9             Je vais de Grenoble à Dijon en voiture.              Dijon   ARR
# 10    Je voyage de Bruxelles à Amsterdam ce week-end.          Bruxelles   ARR
# 11  L'itinéraire commence à Marseille et se termin...          Marseille   ARR
# 12  L'itinéraire commence à Marseille et se termin...             Toulon   DEP
# 13              Je quitte Monaco pour aller à Menton.             Menton   DEP
# 14                     Le bus va de Caen à Cherbourg.               Caen   DEP
# 15                     Le bus va de Caen à Cherbourg.          Cherbourg   ARR
# 16           Il part de Bayonne et arrive à Biarritz.             arrive   ARR
# 17                      Je vais de Chamonix à Annecy.           Chamonix   ARR
# 18                      Je vais de Chamonix à Annecy.             Annecy   ARR
# 19                  Nous roulons de Bastia à Ajaccio.            Ajaccio   ARR
# 20           Je pars de Bordeaux et j'arrive à Paris.           Bordeaux   ARR
# 21                Notre vol va de Madrid à Barcelone.             Madrid   DEP
# 22                Notre vol va de Madrid à Barcelone.          Barcelone   ARR
# 23                Je vais à Paris en partant de Lyon.              Paris   ARR
# 24                Je vais à Paris en partant de Lyon.               Lyon   DEP
